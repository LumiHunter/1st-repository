# %% [markdown]
# ## OCR 모델 비교하기
#
# ### 학습 목표
# - OCR의 과정을 이해합니다.
# - 문자인식 결과의 표현방식을 이해합니다.
# - 파이썬을 통해 OCR을 사용할 수 있습니다.
#
# ### 루브릭
# - OCR을 활용하여 구현하려는 서비스의 기획이 타당한가? : **목표로 하는 서비스가 OCR로 적용 가능하며, OCR을 활용했을 때 더욱 유용해진다.**
# - 모델 평가기준이 명확하고 체계적으로 세워졌는가? : **평가 기준에 부합하는 테스트 데이터의 특징이 무엇인지 명확하게 제시되었다.**
# - 평가기준에 따라 충분한 분량의 테스트가 진행되고 그 결과가 잘 정리되었는가? : **최대 20장까지의 테스트 이미지를 사용해 제시된 평가 기준에 따른 테스트 결과가 잘 정리되어 결론이 도출되었다.**

# %% [markdown]
# ## 사용할 이미지: 영화 크레딧 영상 캡쳐
# - 한국영화 2편, 외화 2편의 크레딧 화면 캡쳐 10장
#
# 영화진흥위원회(KOFIC)에서는 각각의 영화마다 어떤 사람들과 관계사들이 참여했는지에 대한 정보를 수집하여, 영화인, 영화사 등에 대한 DB를 구축, 관리하고 있다. 이들 DB는 각종 지원사업이나 산업 현황 파악 및 연구 등을 목적으로 수집하고 있다.
# 일반적으로 한 편의 영화에 대한 정보는 영화사나 배급사에서 제공하는 것을 바탕으로 하지만, 목적에 필요한 정보가 누락되거나, 영화사로부터 협조를 구하기 어렵거나, 오래된 영화 등의 경우는 담당자가 직접 크레딧 화면을 보고 수기로 정보를 입력해야만 하는 경우가 있다고 한다.
# 이에 OCR 모델을 크레딧 영상 또는 크레딧 영상을 캡쳐한 사진에 적용하여 정보를 정리할 수 있다면 큰 효율을 얻을 수 있을 것으로 보인다.

# %%
import matplotlib.pyplot as plt
import keras_ocr

pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /aiffel/.keras-ocr/craft_mlt_25k.h5
# ...
# Looking for /aiffel/.keras-ocr/crnn_kurapan.h5
# ...

# %% [markdown]
# ## keras-ocr

# %%
image_urls = [
    'https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/TPOTO_1.png', 
    'https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/TPOTO_2.png']

images = [ keras_ocr.tools.read(url) for url in image_urls]
prediction_groups = [pipeline.recognize([url]) for url in image_urls]

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for idx, ax in enumerate(axs):
    keras_ocr.tools.drawAnnotations(image=images[idx], 
                                    predictions=prediction_groups[idx][0], ax=ax)

# %%
for i in range(len(prediction_groups[0][0])):
    print(prediction_groups[0][0][i][0])
# Out:
# cast
# gerard
# the
# phantom
# butler
# christine
# rossum
# emmy
# raoul
# patrick
# wilson
# mme
# giry
# miranda
# richardson
# andre
# simon
# callow
# ciaran
# hinds
# firmin
# kevin
# mcnally
# buquet
# r
# carlotta
# minnie
# driver
# piangi
# victor
# mcguire
# reyer
# murray
# melvin
# ellison
# meg
# giry
# jennifer
# lefevre
# james
# fleet
# carlottals
# maid
# imogen
# bain
# carlottas
# wigmaker
# miles
# western
# carlotta
# ls
# seamstress
# judith
# paris
# passirino
# halcro
# johnston
# auctioneer
# paul
# brooke
# chopping
# porter
# oliver

# %%
for i in range(len(prediction_groups[1][0])):
    print(prediction_groups[1][0][i][0])
# Out:
# opera
# chorus
# arneil
# annalene
# beechey
# mark
# carroll
# david
# valerie
# cutko
# tricia
# deighton
# john
# griffiths
# mandy
# holliday
# kelly
# sophie
# louise
# dann
# terry
# marks
# graham
# brian
# jackie
# mcduff
# wheeler
# julia
# worsley
# ballet
# boys
# chris
# jarvis
# sebastien
# torkia
# ballet
# girls
# greet
# botterman
# elena
# buda
# tess
# cunningham
# liesl
# dowsett
# pia
# kathryn
# dunn
# driver
# sophia
# hurdley
# amy
# lawson
# lucy
# potter
# kirsty
# tapp
# populaire
# opera
# orchestra
# richard
# bayliss
# ralph
# broadbent
# alexander
# cameron
# paul
# costin
# matthew
# draper
# gant
# ben
# jonathon
# hill
# timothy
# kipling
# jonathon
# kitchen
# tristan
# michael
# mansbridge
# moore
# keyte
# jeff
# julian
# james
# purvis
# poole
# pullman
# robert
# dave
# tosh
# chris
# worsey

# %% [markdown]
# cast
# the phantom | gerard butler
# christine | emmy rossum
# ...
#
# opera chorus
# david arneil | annalene beechey | mark carroll | valerie cutko | tricia deighton
# ...
# 오류 없이 띄어쓰기 단위로 단어를 읽는데에는 성공했으나 유효하게 사용하기 위해서는 단어의 순서를 위와 같이 정렬하는 기능이 필요해보인다. 배역명과 배우명 또는 하나의 이름이 3어절로 끊어지는 경우 등에 대한 규칙 설정도 추가로 필요하다.

# %%
image_urls = [
    'https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/HarryPotter_2.png', 
    'https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/HarryPotter_1.png']

images = [ keras_ocr.tools.read(url) for url in image_urls]
prediction_groups = [pipeline.recognize([url]) for url in image_urls]

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for idx, ax in enumerate(axs):
    keras_ocr.tools.drawAnnotations(image=images[idx], 
                                    predictions=prediction_groups[idx][0], ax=ax)

# %%
for i in range(len(prediction_groups[0][0])):
    print(prediction_groups[0][0][i][0])
# Out:
# cast
# order
# of
# appearance
# in
# albus
# dumbledore
# richard
# harris
# professor
# mcgonagall
# maggie
# smith
# hagrid
# robbie
# coltrane
# baby
# harry
# potter
# saunders
# triplets
# harry
# potter
# daniel
# radcliffe
# aunt
# petunia
# dursley
# fiona
# shaw
# dudley
# dursley
# harry
# melling
# uncle
# dursley
# vernon
# richard
# griffiths
# bartender
# leaky
# cauldron
# derek
# deadman
# in
# professor
# quirrell
# ian
# hart
# diagon
# alley
# ben
# borowiecki
# boy
# goblin
# bank
# teller
# warwick
# davis
# griphook
# vern
# troyer
# mr
# ollivander
# john
# hurt
# he
# who
# must
# not
# namedr
# be
# richard
# bremmer
# lily
# potter
# geraldine
# somerville
# station
# guard
# harry
# taylor

# %%
for i in range(len(prediction_groups[1][0])):
    print(prediction_groups[1][0][i][0])
# Out:
# production
# assistants
# luke
# boyle
# kate
# lewis
# phil
# clarke
# charlotte
# brown
# quinn
# robinson
# leeann
# bosley
# david
# sexton
# tilly
# langdon
# alex
# klein
# matthew
# cooke
# clara
# paris
# alan
# saywell
# michael
# wilson
# julian
# ibbitson
# sunita
# parmar
# david
# collier
# poppy
# kay
# nick
# joscylene
# mark
# axtell
# jordan
# crockett
# julia
# dehoff
# stephen
# swain
# sue
# jones
# anna
# maria
# lund
# amanda
# pettett
# nicki
# hughes
# david
# collier
# kate
# newport
# jonny
# benson
# lyndsay
# bullock
# sassica
# francisbruce
# michelle
# hudd
# additional
# first
# assistant
# director
# duncan
# henderson
# additional
# second
# assistant
# director
# r
# mino
# j
# financial
# controller
# john
# trehy
# production
# accountant
# gary
# nixon
# assistant
# accountants
# john
# udall
# peter
# eardley
# trevor
# chalmers
# john
# mulligan
# christian
# holden

# %% [markdown]
# 이 크레딧은 배역명과 배우명 또는 맡은 일과 이름이 다른 글씨체로 작성되어, 인식한 단어를 차례대로 읽으면 'albus
# dumbledore
# richard
# harris' 또는 'production
# assistants
# luke
# boyle'와 같이 최소한의 정렬된 정보값을 읽을 수 있다. 단 구분자 설정은 여전히 필요하다.

# %%
image_urls = [
    'https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/%EC%95%94%EC%82%B4_1.png', 
    'https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/%EA%B2%80%EC%9D%80%EC%82%AC%EC%A0%9C%EB%93%A4_4.png']

images = [ keras_ocr.tools.read(url) for url in image_urls]
prediction_groups = [pipeline.recognize([url]) for url in image_urls]

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for idx, ax in enumerate(axs):
    keras_ocr.tools.drawAnnotations(image=images[idx], 
                                    predictions=prediction_groups[idx][0], ax=ax)

# %% [markdown]
# keras-ocr은 한국어 인식은 지원하지 않으나, 띄어쓰기 단위로 문자 검출에는 성공하고 있다.

# %% [markdown]
# ## Tesseract

# %%
import os
import pytesseract
from PIL import Image
from pytesseract import Output
import matplotlib.pyplot as plt

def crop_word_regions(image_path='./images/sample.png', output_path='./output'):
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    custom_oem_psm_config = r'--oem 3 --psm 3'
    image = Image.open(image_path)

    recognized_data = pytesseract.image_to_data(
        image, lang='eng',    # 한국어라면 lang='kor'
        config=custom_oem_psm_config,
        output_type=Output.DICT
    )
    
    top_level = max(recognized_data['level'])
    index = 0
    cropped_image_path_list = []
    for i in range(len(recognized_data['level'])):
        level = recognized_data['level'][i]
    
        if level == top_level:
            left = recognized_data['left'][i]
            top = recognized_data['top'][i]
            width = recognized_data['width'][i]
            height = recognized_data['height'][i]
            
            output_img_path = os.path.join(output_path, f"{str(index).zfill(4)}.png")
            print(output_img_path)
            cropped_image = image.crop((
                left,
                top,
                left+width,
                top+height
            ))
            cropped_image.save(output_img_path)
            cropped_image_path_list.append(output_img_path)
            index += 1
    return cropped_image_path_list

# %%
work_dir = os.getenv('HOME')+'/aiffel/ocr_python'
img_file_path = work_dir + '/TPOTO_1.png' 

cropped_image_path_list = crop_word_regions(img_file_path, work_dir)
# Out:
# /aiffel/aiffel/ocr_python/0000.png
# /aiffel/aiffel/ocr_python/0001.png
# /aiffel/aiffel/ocr_python/0002.png
# /aiffel/aiffel/ocr_python/0003.png
# /aiffel/aiffel/ocr_python/0004.png
# /aiffel/aiffel/ocr_python/0005.png
# /aiffel/aiffel/ocr_python/0006.png
# /aiffel/aiffel/ocr_python/0007.png
# /aiffel/aiffel/ocr_python/0008.png
# /aiffel/aiffel/ocr_python/0009.png
# /aiffel/aiffel/ocr_python/0010.png
# /aiffel/aiffel/ocr_python/0011.png
# /aiffel/aiffel/ocr_python/0012.png
# /aiffel/aiffel/ocr_python/0013.png
# /aiffel/aiffel/ocr_python/0014.png
# /aiffel/aiffel/ocr_python/0015.png
# /aiffel/aiffel/ocr_python/0016.png
# /aiffel/aiffel/ocr_python/0017.png
# /aiffel/aiffel/ocr_python/0018.png
# /aiffel/aiffel/ocr_python/0019.png
# /aiffel/aiffel/ocr_python/0020.png
# /aiffel/aiffel/ocr_python/0021.png
# /aiffel/aiffel/ocr_python/0022.png
# /aiffel/aiffel/ocr_python/0023.png
# /aiffel/aiffel/ocr_python/0024.png
# /aiffel/aiffel/ocr_python/0025.png
# /aiffel/aiffel/ocr_python/0026.png
# ...

# %%
def recognize_images(cropped_image_path_list):
    custom_oem_psm_config = r'--oem 3 --psm 7'
    
    for image_path in cropped_image_path_list:
        image = Image.open(image_path)
        recognized_data = pytesseract.image_to_string(
            image, lang='eng',    # 한국어라면 lang='kor'
            config=custom_oem_psm_config,
            output_type=Output.DICT
        )
        print(recognized_data['text'])
    print("Done")

# 위에서 준비한 문자 영역 파일들을 인식하여 얻어진 텍스트를 출력합니다.
recognize_images(cropped_image_path_list)
# Out:
# o7.¥ 9 i
#
# seit.
#
# ei
#
# Christine
#
# Raoul
#
# aye bale
#
# Giry
#
# Andre
#
# 3
#
# irmin
#
# Buquet
#
# Carlotta
#
# 1s
#
# lotta
#
# er bits
#
# Keyer
#
# Wt
#
#
# OFT a
#
# le
#
# Code
#
# else
#
# “a
#
# aid
#
# ( ariotta‘s
#
# ira
#
# <er
#
# e
#
# 13
#
# otta’s
#
# eer:
#
# amstress
#
# SS)
#
# Passirino
#
# Auctioneer
#
# Porter
#
# 4
#
# (SERARD
#
# LORE RA
#
# wm hee
#
# ROSSUM
#
# vive ala 4
#
# SER. Oh."
#
# MIRANDA
#
# RICHARDSON
#
# SIMON
#
# C ALLOW
#
# CTARAN
#
# HINDS
#
# ems i
#
# K
#
# McNALLY
#
# vlna die
#
# DRIVER
#
# VICTOR
#
# MeCUIRE
#
# MURRAY
#
# MELVIN
#
# ia bE ss
#
# ELLISON
#
# JAMES
#
# 2a we
#
# IMOGEN
#
# ate
#
# tao
#
# eth a
#
# 18
#
# Bese."
#
# RIS
#
# setae 48
#
# JOHNSTON
#
# PAUL
#
# BROOKE
#
# el1R a sn
#
# CHOPPING
#
# Done

# %% [markdown]
# 단어 분할이 제대로 이루어지지 않거나 분할된 단어를 읽지 못하는 경우가 많이 발생한다. keras-ocr에 비해 읽을 글자가 많을 경우에 취약점을 보이는 듯 하다.

# %%
work_dir = os.getenv('HOME')+'/aiffel/ocr_python'
img_file_path = work_dir + '/TPOTO_1_CUT.png' 

cropped_image_path_list = crop_word_regions(img_file_path, work_dir)
# Out:
# /aiffel/aiffel/ocr_python/0000.png
# /aiffel/aiffel/ocr_python/0001.png
# /aiffel/aiffel/ocr_python/0002.png
# /aiffel/aiffel/ocr_python/0003.png
# /aiffel/aiffel/ocr_python/0004.png
# /aiffel/aiffel/ocr_python/0005.png
# /aiffel/aiffel/ocr_python/0006.png
# /aiffel/aiffel/ocr_python/0007.png
# /aiffel/aiffel/ocr_python/0008.png
# /aiffel/aiffel/ocr_python/0009.png
# /aiffel/aiffel/ocr_python/0010.png
# /aiffel/aiffel/ocr_python/0011.png
# /aiffel/aiffel/ocr_python/0012.png
# /aiffel/aiffel/ocr_python/0013.png
# /aiffel/aiffel/ocr_python/0014.png

# %%
recognize_images(cropped_image_path_list)
# Out:
# o7.¥ 9 i
#
# seit.
#
# ei
#
# Christine
#
# Raoul
#
# aye bale
#
# Giry
#
# (SERARD
#
# LORE RA
#
# wm hee
#
# ROSSUM
#
# vive ala 4
#
# SER. Oh."
#
# MIRANDA
#
# RICHARDSON
#
# Done

# %% [markdown]
# 크레딧 영상 캡쳐 사진을 잘라 인식할 텍스트 수를 대폭 줄였으나 결과는 달라지지 않았다.
# ![줄인 이미지](https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/TPOTO_1_CUT.png)

# %%
work_dir = os.getenv('HOME')+'/aiffel/ocr_python'
img_file_path = work_dir + '/HarryPotter_2.png' 

cropped_image_path_list = crop_word_regions(img_file_path, work_dir)
# Out:
# /aiffel/aiffel/ocr_python/0000.png
# /aiffel/aiffel/ocr_python/0001.png
# /aiffel/aiffel/ocr_python/0002.png
# /aiffel/aiffel/ocr_python/0003.png
# /aiffel/aiffel/ocr_python/0004.png
# /aiffel/aiffel/ocr_python/0005.png
# /aiffel/aiffel/ocr_python/0006.png
# /aiffel/aiffel/ocr_python/0007.png
# /aiffel/aiffel/ocr_python/0008.png
# /aiffel/aiffel/ocr_python/0009.png
# /aiffel/aiffel/ocr_python/0010.png
# /aiffel/aiffel/ocr_python/0011.png
# /aiffel/aiffel/ocr_python/0012.png
# /aiffel/aiffel/ocr_python/0013.png
# /aiffel/aiffel/ocr_python/0014.png
# /aiffel/aiffel/ocr_python/0015.png
# /aiffel/aiffel/ocr_python/0016.png
# /aiffel/aiffel/ocr_python/0017.png
# /aiffel/aiffel/ocr_python/0018.png
# /aiffel/aiffel/ocr_python/0019.png
# /aiffel/aiffel/ocr_python/0020.png
# /aiffel/aiffel/ocr_python/0021.png
# /aiffel/aiffel/ocr_python/0022.png
# /aiffel/aiffel/ocr_python/0023.png
# /aiffel/aiffel/ocr_python/0024.png
# /aiffel/aiffel/ocr_python/0025.png
# /aiffel/aiffel/ocr_python/0026.png
# ...

# %%
recognize_images(cropped_image_path_list)
# Out:
# Cast in
#
# §
#
# atta anth a
#
# earance
#
# Albus
#
# Dumbledore
#
# Professor
#
# McGonagall
#
# Hagrid
#
# EVD Y
#
# seta
#
# Potter
#
# selena atiass:
#
# Aunt
#
# Petunia
#
# Dursley
#
# PTT SY
#
# Dursley
#
# Uncle
#
# Tatts
#
# OTe 5
#
# Bartender
#
# th
#
# FT SY
#
# Cauldron
#
# eat ati
#
# Quirrell
#
# PTET Ziyi
#
# ravi
#
# Tes
#
# Goblin
#
# Bank
#
# erSits:
#
# Cet tee)
#
# iT)
#
#
# Ve
#
# Ollivander
#
# ste
#
# sits
#
# Must
#
# att:
#
# iT:
#
# WET Va ie
#
# Lily
#
# Potter
#
# Station
#
# (;uard
#
# RICHARD
#
# HARRIS
#
# MAGGIE
#
# SMITH
#
# ROBBIE
#
# COLTRANE
#
# aOR EDD ee
#
# TRIPLETS
#
# DF Ve ae
#
# RADCLIFFE
#
# ile 7%
#
# SHAW
#
# HARRY
#
# MELLING
#
# 400} 57
#
# ART
#
# Beg 3h
#
# 2EU:
#
# ft
#
# DEREK
#
# DEADMAN
#
# A
#
# slate
#
# aoa
#
# BOROWIECKI
#
# WARWICK
#
# DAVIS
#
# VERN
#
# 1¥ <0)
#
# Gal
#
# JOHN
#
# she):
#
# 41
#
# RICHARD
#
# BREMMER
#
# C2 aU RPE
#
# SOMERVILLE
#
# HARRY
#
# TAYLOR
#
# Done

# %% [markdown]
# Tesseract를 이용해 영어 크레딧을 읽는 기능은 단어별 구분이 잘 되지 않고, 구분한 단어를 글자로 변환하는 데에 있어 오류도 크다. 또 keras-ocr이 대문자를 일괄 소문자로 바꾸어 저장하는 데에 반해 대문자를 같이 사용하고 특수문자를 출력하는 것으로 보아 문자에 대한 전처리가 필요할 듯 하다.

# %%
work_dir = os.getenv('HOME')+'/aiffel/ocr_python'
img_file_path = work_dir + '/암살_1.png' 

cropped_image_path_list = crop_word_regions(img_file_path, work_dir)
# Out:
# /aiffel/aiffel/ocr_python/0000.png
# /aiffel/aiffel/ocr_python/0001.png
# /aiffel/aiffel/ocr_python/0002.png
# /aiffel/aiffel/ocr_python/0003.png
# /aiffel/aiffel/ocr_python/0004.png
# /aiffel/aiffel/ocr_python/0005.png
# /aiffel/aiffel/ocr_python/0006.png

# %%
def recognize_images(cropped_image_path_list):
    custom_oem_psm_config = r'--oem 3 --psm 7'
    
    for image_path in cropped_image_path_list:
        image = Image.open(image_path)
        recognized_data = pytesseract.image_to_string(
            image, lang='kor',    # 한국어라면 lang='kor'
            config=custom_oem_psm_config,
            output_type=Output.DICT
        )
        print(recognized_data['text'])
    print("Done")

recognize_images(cropped_image_path_list)
# Out:
#  깨
#
#
# [
#
# 가
#
# 토그 8.
#
# 더
#
# 0
#
# Done

# %% [markdown]
# ![크레딧 사진 원본](https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/%EC%95%94%EC%82%B4_1.png)
# 한국 영화 크레딧은 거의 문자를 인식하지 못하고 있다. 문자로 인식한 몇가지도 글자 또는 단어 단위로 인식에 실패하고 있고, 읽어내지 못했다.

# %%
work_dir = os.getenv('HOME')+'/aiffel/ocr_python'
img_file_path = work_dir + '/검은사제들_4.png' 

cropped_image_path_list = crop_word_regions(img_file_path, work_dir)
# Out:
# /aiffel/aiffel/ocr_python/0000.png
# /aiffel/aiffel/ocr_python/0001.png
# /aiffel/aiffel/ocr_python/0002.png
# /aiffel/aiffel/ocr_python/0003.png
# /aiffel/aiffel/ocr_python/0004.png
# /aiffel/aiffel/ocr_python/0005.png
# /aiffel/aiffel/ocr_python/0006.png
# /aiffel/aiffel/ocr_python/0007.png
# /aiffel/aiffel/ocr_python/0008.png
# /aiffel/aiffel/ocr_python/0009.png
# /aiffel/aiffel/ocr_python/0010.png
# /aiffel/aiffel/ocr_python/0011.png
# /aiffel/aiffel/ocr_python/0012.png
# /aiffel/aiffel/ocr_python/0013.png
# /aiffel/aiffel/ocr_python/0014.png
# /aiffel/aiffel/ocr_python/0015.png
# /aiffel/aiffel/ocr_python/0016.png
# /aiffel/aiffel/ocr_python/0017.png
# /aiffel/aiffel/ocr_python/0018.png
# /aiffel/aiffel/ocr_python/0019.png
# /aiffel/aiffel/ocr_python/0020.png
# /aiffel/aiffel/ocr_python/0021.png
# /aiffel/aiffel/ocr_python/0022.png
# /aiffel/aiffel/ocr_python/0023.png
# /aiffel/aiffel/ocr_python/0024.png
# /aiffel/aiffel/ocr_python/0025.png
# /aiffel/aiffel/ocr_python/0026.png
# ...

# %%
recognize_images(cropped_image_path_list)
# Out:
# “620.
#
# 1
#
# ~
#
# 10] ㅣ] ^
#
# 도
#
# <
#
# 미술&소풍
#
# 켜
#
# 맨하본 히비 에메
#
# 년
#
# 녹
#
# 7
#
# /
#
# /
#
# 분
#
# 5 - 버으
#
# 00
#
# ~,
#
# 40016
#
# 2
#
# 았한
#
# ~
#
# 80;
#
# 나돌].
#
# 7 주
#
# 8 그이.
#
# 보나<최후의
#
# 으
#
# 고:
#
# 이은희 노엘라<승리의
#
# 보사,
#
# 도
#
# 로
#
# 10:
#
# "스
#
# 기은
#
# 0
#
# Done

# %% [markdown]
# ![이미지 원본 2](https://raw.githubusercontent.com/LumiHunter/AIFFEL-exploration/master/%EA%B2%80%EC%9D%80%EC%82%AC%EC%A0%9C%EB%93%A4_4.png)
# 상호 로고 등 큰 글자도 tesseract는 거의 인식하지 못하고 있다.

# %% [markdown]
# ## 회고
# - 영화 크레딧은 대부분 까만 화면에 글씨만 나열되어 있는 영상(이미지)이기 때문에, 인식이 쉬울 것이라고 예상했지만 Tesseract의 경우에는 그렇지 않은 것으로 보인다. Tesseract는 문자 검출 단계와 문자 인식 단계 모두에서 취약점을 보였다.
# - 본 목적에 부합하여 사용할 수 있는 모델은 Tesseract보다는 keras-ocr로 보인다. keras-ocr에 한국어 인식 학습을 보강하고, 인식한 텍스트를 사용자가 정렬할 수 있도록 하면 활용이 가능하지 않을까 기대해본다.
# - 글자를 검출하고 그 글자를 활용할 수 있는 단어의 단위로 쪼개어 정렬하는 작업은 결국 이미지 처리와 자연어 처리 둘 모두에 해당되는 과제이다. 특히 Tesseract는 한국어 자모음을 하나의 문자로 인식하지 못해 'ㅅ' 하나만을 문자로 인식하기도 했고, 한글이나 한자 등은 글자가 만들어지는 경우의 수가 알파벳에 비해 훨씬 많기 때문에 각각의 글자 모양을 학습시키는 작업이 매우 어려울 것으로 예상되는데, 그 부분을 어떻게 처리하면 좋을지 궁금하다.
